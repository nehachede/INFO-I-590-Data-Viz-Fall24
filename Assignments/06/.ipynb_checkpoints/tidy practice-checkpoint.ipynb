# %%
import pandas as pd

# %%
df = pd.read_csv("daily_show_guests.csv")
df.head()
# Out:
#    YEAR GoogleKnowlege_Occupation     Show   Group    Raw_Guest_List
# 0  1999                     actor  1/11/99  Acting    Michael J. Fox
# 1  1999                  Comedian  1/12/99  Comedy   Sandra Bernhard
# 2  1999        television actress  1/13/99  Acting     Tracey Ullman
# 3  1999              film actress  1/14/99  Acting  Gillian Anderson
# 4  1999                     actor  1/18/99  Acting  David Alan Grier

# %% [markdown]
# In tidy data:
# 1. Each variable forms a column.
# 2. Each observation forms a row.
# 3. Each type of observational unit forms a table.

# %%
df.GoogleKnowlege_Occupation.unique()
# Out:
# array(['actor', 'Comedian', 'television actress', 'film actress',
#        'Singer-lyricist', 'model', 'stand-up comedian', 'actress',
#        'comedian', 'Singer-songwriter', 'television personality', 'Comic',
#        'rock band', 'musician', 'Film actor', 'Model', 'journalist', nan,
#        'singer-songwriter', 'us senator', 'film actor', 'pianist',
#        'Vocalist', 'writer', 'Stand-up comedian', 'Film director',
#        'singer', 'television host', 'televison actor', 'muppet',
#        'director', 'film director', 'american television personality',
#        'rapper', 'football player', 'former mayor of cincinatti',
#        'Film actress', 'businesswoman', 'activist', 'Media person',
#        'former us senator', 'american politician', 'Filmmaker',
#        'radio personality', 'commentator', 'Journalist',
#        'former senator from kansas', 'Reporter', 'Singer',
#        'professional wrestler', 'publisher', 'reality show contestant',
# ...
